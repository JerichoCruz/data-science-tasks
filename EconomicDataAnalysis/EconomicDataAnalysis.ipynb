# %% [markdown]
# # Economic Data Analysis with Fred & Pandas
#
# This is an example of how to pull data, visualize and discover insights using python pandas.
#
# We will be using data from Federal Reserve Economic Data (FRED), which is an online database consisting of hundreds of thousands of economic data time series from a multitude of sources.
#
# Fred is not available by default within jupyter notebook but we will install the fredapi using the pip command seen below.

# %%
# !pip install fredapi

# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

plt.style.use('fivethirtyeight')
# pd.set_option('max_columns', 500)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

from fredapi import Fred

# Request Fred API Key from:
# https://fred.stlouisfed.org/docs/api/fred/#API
fred_key = 'Your key here'

# %% [markdown]
# ### 1. Create the Fred object

# %%
fred = Fred(api_key=fred_key)

# %% [markdown]
# ### 2. Search for economic data

# %%
sp_search = fred.search('SP', order_by='popularity') # https://fred.stlouisfed.org/series/SP500
sp_search.head()
# Out:
#                     id realtime_start realtime_end  \
# series id
# CSUSHPINSA  CSUSHPINSA     2022-06-09   2022-06-09
# SP500            SP500     2022-06-09   2022-06-09
# CSUSHPISA    CSUSHPISA     2022-06-09   2022-06-09
# DJIA              DJIA     2022-06-09   2022-06-09
# SPCS20RSA    SPCS20RSA     2022-06-09   2022-06-09
#
#                                                         title  \
# series id
# CSUSHPINSA    S&P/Case-Shiller U.S. National Home Price Index
# SP500                                                 S&P 500
# CSUSHPISA     S&P/Case-Shiller U.S. National Home Price Index
# DJIA                             Dow Jones Industrial Average
# SPCS20RSA   S&P/Case-Shiller 20-City Composite Home Price ...
#
#            observation_start observation_end     frequency frequency_short  \
# series id
# CSUSHPINSA        1987-01-01      2022-03-01       Monthly               M
# SP500             2012-06-11      2022-06-09  Daily, Close               D
# CSUSHPISA         1987-01-01      2022-03-01       Monthly               M
# DJIA              2012-06-11      2022-06-09  Daily, Close               D
# SPCS20RSA         2000-01-01      2022-03-01       Monthly               M
#
#                          units         units_short      seasonal_adjustment  \
# series id
# CSUSHPINSA  Index Jan 2000=100  Index Jan 2000=100  Not Seasonally Adjusted
# SP500                    Index               Index  Not Seasonally Adjusted
# CSUSHPISA   Index Jan 2000=100  Index Jan 2000=100      Seasonally Adjusted
# DJIA                     Index               Index  Not Seasonally Adjusted
# SPCS20RSA   Index Jan 2000=100  Index Jan 2000=100      Seasonally Adjusted
#
#            seasonal_adjustment_short              last_updated popularity  \
# series id
# CSUSHPINSA                       NSA 2022-05-31 08:02:01-05:00         91
# SP500                            NSA 2022-06-09 19:11:00-05:00         84
# CSUSHPISA                         SA 2022-05-31 08:02:02-05:00         80
# DJIA                             NSA 2022-06-09 19:01:05-05:00         74
# SPCS20RSA                         SA 2022-05-31 08:02:03-05:00         72
#
#                                                         notes
# series id
# CSUSHPINSA  For more information regarding the index, plea...
# SP500       The observations for the S&P 500 represent the...
# CSUSHPISA   For more information regarding the index, plea...
# DJIA        The observations for the Dow Jones Industrial ...
# SPCS20RSA   For more information regarding the index, plea...

# %%
in_search = fred.search('T5YIE') # 5-Year Breakeven Inflation Rate https://fred.stlouisfed.org/series/T5YIE
in_search.head()
# Out:
#           frequency frequency_short     id              last_updated  \
# series id
# T5YIE         Daily               D  T5YIE 2022-06-09 16:01:19-05:00
#
#                                                        notes observation_end  \
# series id
# T5YIE      The breakeven inflation rate represents a meas...      2022-06-09
#
#           observation_start popularity realtime_end realtime_start  \
# series id
# T5YIE            2003-01-02         89   2022-06-09     2022-06-09
#
#                seasonal_adjustment seasonal_adjustment_short  \
# series id
# T5YIE      Not Seasonally Adjusted                       NSA
#
#                                      title    units units_short
# series id
# T5YIE      5-Year Breakeven Inflation Rate  Percent           %

# %% [markdown]
# ### 3. Pull Raw Data & Plot

# %%
sp500 = fred.get_series(series_id='SP500', observation_start='6/8/2017', observation_end='6/8/2022')
plt.ylabel('USD $')
sp500.plot(figsize=(10, 5), title='S&P 500', lw=2)
# Out:
# <AxesSubplot:title={'center':'S&P 500'}, ylabel='USD $'>

# %%
t5yinflation = fred.get_series(series_id='T5YIE', observation_start='6/8/2017',  observation_end='6/8/2022')
plt.ylabel('Percentage %')
t5yinflation.plot(figsize=(10, 5), title='5-Year Breakeven Inflation Rate', color=color_pal[1], lw=2)
# Out:
# <AxesSubplot:title={'center':'5-Year Breakeven Inflation Rate'}, ylabel='Percentage %'>

# %% [markdown]
# ### 4. Plot both data series together

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx()
sp500.plot(figsize=(10, 5), ax=ax, label='S&P 500', lw=2)
t5yinflation.plot(ax=ax2, label='Inflation', color=color_pal[1], lw=2)
ax2.grid(False) # Turn grid off on second line
ax.set_title('S&P 500 Index compared to Inflation Rate')
# Out:
# Text(0.5, 1.0, 'S&P 500 Index compared to Inflation Rate')
